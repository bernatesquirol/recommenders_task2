# %%
import pandas as pd
import numpy as np
import math

# %%
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv('data/ml-100k/u.user', sep='|', names=u_cols, dtype={'user_id':str})

r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv('data/ml-100k/u.data', sep='\t', names=r_cols, dtype={'movie_id':str, 'user_id':str})

m_cols = ['movie_id', 'title', 'release_date']
movies = pd.read_csv('data/ml-100k/u.item', sep='|', names=m_cols, usecols=range(3), encoding='latin-1', dtype={'movie_id':str})

data = pd.merge(pd.merge(ratings, users), movies)
data = data[['user_id','title', 'movie_id','rating','release_date','sex','age']]


print("BD has", str(data.shape[0]),"ratings")
print("BD has",data.user_id.nunique(),"users")
print("BD has",data.movie_id.nunique(),"movies")
data.head()
# Out:
# BD has 100000 ratings
# BD has 943 users
# BD has 1682 movies
#   user_id         title movie_id  rating release_date sex  age
# 0     196  Kolya (1996)      242       3  24-Jan-1997   M   49
# 1     305  Kolya (1996)      242       5  24-Jan-1997   M   23
# 2       6  Kolya (1996)      242       4  24-Jan-1997   M   42
# 3     234  Kolya (1996)      242       4  24-Jan-1997   M   60
# 4      63  Kolya (1996)      242       3  24-Jan-1997   M   31

# %%
def assign_to_set(df):
    sampled_ids = np.random.choice(df.index,
                                   size=np.int64(np.ceil(df.index.size * 0.2)),
                                   replace=False)
    df.loc[sampled_ids, 'for_testing'] = True
    return df

data['for_testing'] = False
grouped = data.groupby('user_id', group_keys=False).apply(assign_to_set)
data_train = data[grouped.for_testing == False]
data_test = data[grouped.for_testing == True]
print(data_train.shape)
print(data_test.shape)
print(data_train.index & data_test.index)

print("Training data_set has", str(data_train.shape[0]),"ratings")
print("Test data set has", str(data_test.shape[0]),"ratings")
print("La BD has", data.movie_id.nunique(), "movies")
# Out:
# (79619, 8)
# (20381, 8)
# Int64Index([], dtype='int64')
# Training data_set has 79619 ratings
# Test data set has 20381 ratings
# La BD has 1682 movies

# %%
data_train = pd.read_pickle('data_train.pkl')

# %%
data_test = pd.read_pickle('data_train.pkl')

# %% [markdown]
# ##### How to get the set of movies from user with id  "1"?

# %%
def pivot_db(ratings, adjust_users=False):
    ratings_pivoted = ratings.pivot(
        index='movie_id',
        columns='user_id',
        values='rating'
    )
    if adjust_users:
        ratings_pivoted = ratings_pivoted.apply(lambda u: u-u.mean(), axis=0)
    ratings_pivoted['users_rated']=ratings_pivoted.apply(lambda m: m[-m.isnull()].index, axis=1)    
    return ratings_pivoted#.fillna(0)

# %%
# users = data_train_pivoted['users_rated'].iloc[0]

# %%
def sim_euclid(a,b):
    from scipy.spatial.distance import euclidean
    return 1.0/(1.0+euclidean(a,b))

# %%
def sim_pearson(a,b):
    from scipy.spatial.distance import correlation
    return 1-correlation(a,b)

# %%
def sim_cosine(a,b):
    from scipy.spatial.distance import cosine
    return 1-cosine(a,b)

# %%
def compare(pivoted_m1, pivoted_m2, similarity):
#     m1 = df.loc[m_id1]
#     m2 = df.loc[m_id2]
    if (len(pivoted_m1)==0 or len(pivoted_m2)==0):
        return 1
    users_1 = pivoted_m1['users_rated']
    users_2 = pivoted_m2['users_rated']
    intersection = users_1[users_1.isin(users_2)]
    if len(intersection)==0: 
        return 1
    return similarity(pivoted_m1.loc[intersection], pivoted_m2.loc[intersection])

# %%
from tqdm import tqdm

# %%
class CollaborativeItemReco:
    """ Collaborative filtering using a custom sim(u,u'). """    
    def __init__(self, ratings, similarity, adjust_users=False, k=None, sim_matrix_path=None):
        """ Constructor """        
        self.df = pivot_db(ratings, adjust_users)        
        self.similarity=similarity
        if not sim_matrix_path:
            self.sim_matrix = pd.DataFrame(1, columns=self.df.index, index=self.df.index)
        else:
            self.sim_matrix = pd.read_pickle(sim_matrix_path)
        self.k = k+1 if k else len(self.df.index)
    def learn(self):
        """ Prepare data structures for estimation. Similarity matrix for users """
        for i, mId1 in enumerate(tqdm(self.df.index)):
            for j, mId2 in enumerate(self.df.index[i+1:]):
                sim = compare(self.df.loc[mId1],self.df.loc[mId2], self.similarity)
                self.sim_matrix.loc[mId1,mId2]=sim
                self.sim_matrix.loc[mId2,mId1]=sim
                
    def estimate_basic(self, u, j):
        # u is user
        # j is movie
        if u not in self.df:
            print('u_{} not in training'.format(u))
            return 3
        if j not in self.sim_matrix:
            print('m_{} not in training'.format(j))
            return 3
        u_ratings = self.df[u][self.df[u]>0]
        num=0
        den=0
        P_k = self.sim_matrix[j].loc[u_ratings.index].sort_values(ascending=False).iloc[1:self.k]
        means_movies = self.df.apply(lambda m: m.loc[m['users_rated']].mean(),axis=1)
        for i, sim in P_k.iteritems():
            num+=sim*u_ratings[i]
            den+=sim
        if den==0: 
            if means_movies[j]>0:
                # return the mean movie rating if there is no similar for the computation
                return means_movies[j]
            else:
                # else return mean user rating 
                return u_ratings.mean()
        return num/den
    
    def estimate_mean(self, u, j):
        # u is user
        # j is movie
        if u not in self.df:
            print('u_{} not in training'.format(u))
            return 3
        if j not in self.sim_matrix:
            print('m_{} not in training'.format(j))
            return 3
        u_ratings = self.df[u][self.df[u]>0]
        num=0
        den=0
        P_k = self.sim_matrix[j].loc[u_ratings.index].sort_values(ascending=False).iloc[1:]
        means_movies = self.df.apply(lambda m: m.loc[m['users_rated']].mean(),axis=1)
        for i, sim in P_k.iteritems():
            r_i_mean = means_movies[i]
            num+=sim*(u_ratings[i]-r_i_mean)
            den+=sim
        if den==0: 
            if means_movies[j]>0:
                # return the mean movie rating if there is no similar for the computation
                return means_movies[j]
            else:
                # else return mean user rating 
                return u_ratings.mean()
        return means_movies[j]+num/den

# %%
# data_train_sample = data_train[data_train.movie_id.apply(lambda x: int(x)<100)]
# data_test_sample = data_test[data_test.movie_id.apply(lambda x: int(x)<100)]

# %%
# item_cosine_sample = CollaborativeItemReco(data_train_sample, sim_cosine)
# item_cosine_sample.learn()

# %%
item_cosine_sample.estimate_mean("1","1")
# Out:
# 4.1127366135337615

# %%
# data_test = data_test[data_test.movie_id.apply(lambda x: int(x)<100)]

# %%
item_cosine = CollaborativeItemReco(data_train, sim_cosine, sim_matrix_path='cosine.pkl')
# item_cosine.learn()

# %%
# item_cosine.estimate_mean("1","1")

# %%
# item_cosine.sim_matrix.to_pickle('cosine.pkl')

# %%
item_cosine_adjusted = CollaborativeItemReco(data_train, sim_cosine, adjust_users=True, sim_matrix_path='cosine_adjusted.pkl')
# item_cosine_adjusted.learn()

# %%
# item_cosine_adjusted.sim_matrix.to_pickle('cosine_adjusted.pkl')

# %%
item_pearson = CollaborativeItemReco(data_train, sim_pearson, sim_matrix_path='pearson.pkl')
# item_pearson.learn()

# %%
# item_pearson.sim_matrix.to_pickle('pearson.pkl')

# %%
item_pearson_adjusted = CollaborativeItemReco(data_train, sim_pearson, adjust_users=True, sim_matrix_path='pearson_adjusted.pkl')
# item_pearson_adjusted.learn()

# %%
# item_pearson_adjusted.sim_matrix.to_pickle('pearson_adjusted.pkl')

# %%
item_euclid = CollaborativeItemReco(data_train, sim_euclid, sim_matrix_path='euclid.pkl')
# item_euclid.learn()

# %%
# item_euclid.sim_matrix.to_pickle('euclid.pkl')

# %%
# data

# %%
def compute_rmse(y_pred, y_true):
    """ Compute Root Mean Squared Error. """
    return np.sqrt(np.mean(np.power(y_pred - y_true, 2)))

# %%
def evaluate(estimate_f,data_train,data_test):
    """ RMSE-based predictive performance evaluation with pandas. """
    u_train = set(data_train.user_id)
    m_train = set(data_train.movie_id)
    estimated = np.array([estimate_f(u,i) for (u,i) in zip(data_test.user_id, data_test.movie_id)])
    real = data_test.rating.values
    return compute_rmse(estimated, real)

# %%
import importlib
import tqdm
importlib.reload(tqdm)
# Out:
# <module 'tqdm' from 'C:\\Users\\annae\\miniconda3\\lib\\site-packages\\tqdm\\__init__.py'>

# %%
all_models = {'cosine':item_cosine, 'cosine_adj':item_cosine_adjusted, 'pearson':item_pearson, 'pearson_adj':item_pearson_adjusted, 'euclid':item_euclid}

# %%
# evaluate(model.estimate_basic, data_train, data_test.sample(1))
data_small_test = data_test.sample(5000)

# %%
rmse = []
for model_label, model in all_models.items():
    print('--------- {} ---------'.format(model_label))
    rmse.append(evaluate(model.estimate_basic, data_train, data_small_test))
    print('RMSE basic of {}: {}'.format(model_label,rmse[-1]))
    rmse.append(evaluate(model.estimate_mean, data_train, data_small_test))
    print('RMSE mean of {}: {}'.format(model_label,rmse[-1]))
# Out:
# --------- cosine ---------
# RMSE basic of cosine: 1.0398174011473917
# RMSE mean of cosine: 0.9193122545127611
# --------- cosine_adj ---------

# %%
item_cosine_adjusted.sim_matrix
# Out:
# movie_id         1        10       100      1000      1001      1002  \
# movie_id
# 1         1.000000  0.025098  0.162196 -0.875737 -0.117133 -0.046471
# 10        0.025098  1.000000  0.116664  1.000000  1.000000 -1.000000
# 100       0.162196  0.116664  1.000000 -0.817677 -0.727805 -0.730226
# 1000     -0.875737  1.000000 -0.817677  1.000000  1.000000  0.854249
# 1001     -0.117133  1.000000 -0.727805  1.000000  1.000000 -0.174419
# ...            ...       ...       ...       ...       ...       ...
# 995      -0.219901  0.571167 -0.034903  1.000000  1.000000  1.000000
# 996      -0.562044  1.000000 -0.859685  0.876966 -1.000000  1.000000
# 997      -0.677364  0.083036 -0.402282  0.967888 -0.490367  1.000000
# 998      -0.564178 -0.477636  0.358543  1.000000  1.000000 -1.000000
# 999      -0.580007  1.000000 -0.682630 -1.000000  1.000000  1.000000
#
# movie_id      1003      1004      1005      1006  ...       990       991  \
# movie_id                                          ...
# 1         0.708204 -0.909721 -0.492082 -0.674801  ...  0.009940 -0.671812
# 10       -0.129503  1.000000  0.391735  0.316081  ... -0.950209 -0.256820
# 100      -0.917233  0.214148  0.650415 -0.174623  ...  0.096840 -0.647018
# 1000      1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# 1001      1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# ...            ...       ...       ...       ...  ...       ...       ...
# 995      -1.000000  1.000000  1.000000  1.000000  ... -0.139150  1.000000
# 996       1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# 997       0.563062  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# 998       1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# 999       1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
#
# movie_id  992       993       994       995       996       997       998  \
# movie_id
# 1         1.0  0.124780  0.559209 -0.219901 -0.562044 -0.677364 -0.564178
# 10        1.0 -1.000000 -1.000000  0.571167  1.000000  0.083036 -0.477636
# 100       1.0  0.259696 -0.280391 -0.034903 -0.859685 -0.402282  0.358543
# 1000      1.0 -1.000000  1.000000  1.000000  0.876966  0.967888  1.000000
# 1001      1.0 -1.000000  1.000000  1.000000 -1.000000 -0.490367  1.000000
# ...       ...       ...       ...       ...       ...       ...       ...
# 995       1.0 -1.000000  1.000000  1.000000  1.000000 -1.000000 -1.000000
# 996       1.0 -0.035374  1.000000  1.000000  1.000000  0.818792  1.000000
# 997       1.0  1.000000  1.000000 -1.000000  0.818792  1.000000  0.975430
# 998       1.0  0.863904  1.000000 -1.000000  1.000000  0.975430  1.000000
# 999       1.0  1.000000  1.000000  1.000000  0.188672 -0.463109  1.000000
#
# movie_id       999
# movie_id
# 1        -0.580007
# 10        1.000000
# 100      -0.682630
# 1000     -1.000000
# 1001      1.000000
# ...            ...
# 995       1.000000
# 996       0.188672
# 997      -0.463109
# 998       1.000000
# 999       1.000000
#
# [1653 rows x 1653 columns]

# %%
pd.read_pickle('pearson.pkl')
# Out:
# movie_id         1        10       100      1000      1001      1002  1003  \
# movie_id
# 1         1.000000  0.220107  0.039075  0.333333 -0.413670  1.000000   1.0
# 10        0.220107  1.000000 -0.052973  1.000000       NaN       NaN   NaN
# 100       0.039075 -0.052973  1.000000  1.000000  0.064875  0.485643   NaN
# 1000      0.333333  1.000000  1.000000  1.000000       NaN       NaN   NaN
# 1001     -0.413670       NaN  0.064875       NaN  1.000000 -0.188982   1.0
# ...            ...       ...       ...       ...       ...       ...   ...
# 995       0.353553  1.000000  0.224733  1.000000  1.000000  1.000000   NaN
# 996       0.360041       NaN  0.707107       NaN       NaN       NaN   1.0
# 997       0.273861       NaN  0.740741       NaN  1.000000       NaN   NaN
# 998       0.171499  1.000000  0.883883  1.000000  1.000000       NaN   1.0
# 999       0.000000  1.000000       NaN       NaN       NaN  1.000000   1.0
#
# movie_id    1004      1005      1006  ...       990       991  992       993  \
# movie_id                              ...
# 1         0.5000  0.000000 -0.350000  ...  0.743792 -0.188982  1.0  0.232586
# 10        1.0000  0.500000  1.000000  ...  1.000000 -1.000000  1.0       NaN
# 100       0.6875  0.294884  0.266254  ...  0.634762 -0.232625  1.0  0.113739
# 1000      1.0000  1.000000  1.000000  ...  1.000000  1.000000  1.0       NaN
# 1001      1.0000  1.000000  1.000000  ...       NaN       NaN  1.0       NaN
# ...          ...       ...       ...  ...       ...       ...  ...       ...
# 995       1.0000       NaN       NaN  ...  0.307794       NaN  1.0       NaN
# 996          NaN       NaN       NaN  ...  1.000000  1.000000  1.0  0.500000
# 997          NaN       NaN       NaN  ...  1.000000  1.000000  1.0       NaN
# 998       1.0000       NaN  1.000000  ...  1.000000  1.000000  1.0       NaN
# 999          NaN       NaN       NaN  ...  1.000000  1.000000  1.0  1.000000
#
# movie_id       994       995       996       997       998  999
# movie_id
# 1              NaN  0.353553  0.360041  0.273861  0.171499  0.0
# 10             NaN  1.000000       NaN       NaN  1.000000  1.0
# 100       0.547723  0.224733  0.707107  0.740741  0.883883  NaN
# 1000      1.000000  1.000000       NaN       NaN  1.000000  NaN
# 1001      1.000000  1.000000       NaN  1.000000  1.000000  NaN
# ...            ...       ...       ...       ...       ...  ...
# 995            NaN  1.000000  1.000000       NaN       NaN  1.0
# 996            NaN  1.000000  1.000000  0.577350       NaN  1.0
# 997            NaN       NaN  0.577350  1.000000  1.000000  0.5
# 998       1.000000       NaN       NaN  1.000000  1.000000  NaN
# 999            NaN  1.000000  1.000000  0.500000       NaN  1.0
#
# [1653 rows x 1653 columns]

# %%
# evaluate(item_cosine_sample.estimate_basic, data_train_sample, data_test_sample)

# %%
# print('RMSE for Collaborative Recomender: %s' % evaluate(item_cosine.estimate_mean,data_train,data_test))

# %%
# print('RMSE for Collaborative Recomender: %s' % evaluate(item_cosine.estimate_basic,data_train,data_test))

# %%
def precision_recall(estimate_f, data_train, data_test, N=25):
    all_movies_ids = set(data_train.movie_id.values).union(set(data_train.movie_id.values))
    in_top = 0
    ratings_5_test = data_test[data_test.rating==5]
    print(len(ratings_5_test))
    for i, row in ratings_5_test.iterrows():
        user_seen = list(data_train[data_train.user_id==row.user_id].movie_id.values)+list(data_test[data_test.user_id==row.user_id].movie_id.values)
        unseen = all_movies_ids.difference(user_seen)
        choosen_unseen = np.random.choice(list(unseen), min(len(unseen), 100), replace=False)
        ranked_random = pd.Series(list(map(lambda i:estimate_f(u=row.user_id,j=i),choosen_unseen))+[estimate_f(row.user_id, row.movie_id)],index=list(choosen_unseen)+[row.movie_id])
        index_row = np.argwhere(ranked_random.sort_values(ascending=False).index.values==row.movie_id).flatten()[0]
        if index_row<25:
            in_top+=1
    return in_top/len(ratings_5_test)
#     print(row.user_id)
#     break

# %%
rmse = []
for model_label, model in all_models.items():
    print('--------- {} ---------'.format(model_label))
    rmse.append(precision_recall(model.estimate_basic, data_train, data_small_test))
    print('P/R basic of {}: {}'.format(model_label,rmse[-1]))
    rmse.append(precision_recall(model.estimate_mean, data_train, data_small_test))
    print('P/R mean of {}: {}'.format(model_label,rmse[-1]))
# Out:
# --------- cosine ---------
# 1096
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-61f572c09472> in <module>
#       2 for model_label, model in all_models.items():
#       3     print('--------- {} ---------'.format(model_label))
# ----> 4     rmse.append(precision_recall(model.estimate_basic, data_train, data_small_test))
#       5     print('P/R basic of {}: {}'.format(model_label,rmse[-1]))
#       6     rmse.append(precision_recall(model.estimate_mean, data_train, data_small_test))
#
# <ipython-input-48-065bf87b1583> in precision_recall(estimate_f, data_train, data_test, N)
#       8         unseen = all_movies_ids.difference(user_seen)
#       9         choosen_unseen = np.random.choice(list(unseen), min(len(unseen), 100), replace=False)
# ---> 10         ranked_random = pd.Series(list(map(lambda i:estimate_f(u=row.user_id,j=i),choosen_unseen))+[estimate_f(row.user_id, row.movie_id)],index=list(choosen_unseen)+[row.movie_id])
#      11         index_row = np.argwhere(ranked_random.sort_values(ascending=False).index.values==row.movie_id).flatten()[0]
#      12         if index_row<25:
#
# <ipython-input-48-065bf87b1583> in <lambda>(i)
#       8         unseen = all_movies_ids.difference(user_seen)
#       9         choosen_unseen = np.random.choice(list(unseen), min(len(unseen), 100), replace=False)
# ---> 10         ranked_random = pd.Series(list(map(lambda i:estimate_f(u=row.user_id,j=i),choosen_unseen))+[estimate_f(row.user_id, row.movie_id)],index=list(choosen_unseen)+[row.movie_id])
#      11         index_row = np.argwhere(ranked_random.sort_values(ascending=False).index.values==row.movie_id).flatten()[0]
#      12         if index_row<25:
#
# <ipython-input-25-75d37f034ee4> in estimate_basic(self, u, j)
#      31         den=0
#      32         P_k = self.sim_matrix[j].loc[u_ratings.index].sort_values(ascending=False).iloc[1:self.k]
# ---> 33         means_movies = self.df.apply(lambda m: m.loc[m['users_rated']].mean(),axis=1)
#      34         for i, sim in P_k.iteritems():
#      35             num+=sim*u_ratings[i]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-25-75d37f034ee4> in <lambda>(m)
#      31         den=0
#      32         P_k = self.sim_matrix[j].loc[u_ratings.index].sort_values(ascending=False).iloc[1:self.k]
# ---> 33         means_movies = self.df.apply(lambda m: m.loc[m['users_rated']].mean(),axis=1)
#      34         for i, sim in P_k.iteritems():
#      35             num+=sim*u_ratings[i]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11213             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11214         return self._reduce(
# > 11215             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11216         )
#   11217
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# -> 3891                 return op(delegate, skipna=skipna, **kwds)
#    3892
#    3893         # TODO(EA) dispatch to Index
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      67             try:
#      68                 with np.errstate(invalid="ignore"):
# ---> 69                     return f(*args, **kwargs)
#      70             except ValueError as e:
#      71                 # we want to transform an object array
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     123                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     124             else:
# --> 125                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     126
#     127             return result
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     525     """
#     526     values, mask, dtype, dtype_max, _ = _get_values(
# --> 527         values, skipna, fill_value=0, mask=mask
#     528     )
#     529     dtype_sum = dtype_max
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _get_values(values, skipna, fill_value, fill_value_typ, mask)
#     281     assert is_scalar(fill_value)
#     282
# --> 283     mask = _maybe_get_mask(values, skipna, mask)
#     284
#     285     if is_datetime64tz_dtype(values):
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _maybe_get_mask(values, skipna, mask)
#     227
#     228         if skipna:
# --> 229             mask = isna(values)
#     230
#     231     return mask
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in isna(obj)
#     124     Name: 1, dtype: bool
#     125     """
# --> 126     return _isna(obj)
#     127
#     128
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in _isna_new(obj)
#     150         ),
#     151     ):
# --> 152         return _isna_ndarraylike(obj)
#     153     elif isinstance(obj, ABCGeneric):
#     154         return obj._constructor(obj._data.isna(func=isna))
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in _isna_ndarraylike(obj)
#     254             result = np.empty(shape, dtype=bool)
#     255             vec = libmissing.isnaobj(values.ravel())
# --> 256             result[...] = vec.reshape(shape)
#     257
#     258     elif needs_i8_conversion(dtype):
#
# KeyboardInterrupt:

# %%
precision_recall(item_cosine.estimate_basic,data_train,data_small_test)
# Out:
# 1
# 0.0

# %%
len(data_train)
# Out:
# 11501

# %%
# data_test, data_train

# %%
def rank(u,i):
    return np.sum([int(c) for c in i])

# %%
# Out:
# Index(['98', '97', '69', '78', '77', '86', '85', '76', '58', '49', '57', '84',
#        '75', '39', '93', '48', '74', '38', '19', '37', '82', '91', '55', '46',
#        '72', '9', '54', '36', '45', '18', '8', '35', '26', '53', '25', '43',
#        '34', '15', '6', '51', '14', '23', '5', '3', '20', '11'],
#       dtype='object')

# %%
# Out:
# 34

# %%
np.where(ranked_random.sort_values(ascending=False).index==row.movie_id)
# Out:
# array([[37],
#        [38]], dtype=int64)

# %%
data_train.user_id

# %%
for u,i in ids_to_estimate:
    print(u,i, str(u) in data_train.user_id)
# Out:
# 92 67 False
# 110 67 False
# 184 67 False
# 326 67 False
# 453 67 False
# 622 67 False
# 643 67 False
# 684 67 False
# 712 67 False
# 727 67 False
# 741 67 False
# 833 67 False
# 868 67 False
# 892 67 False
# 196 25 False
# 157 25 False
# 99 25 False
# 59 25 False
# 243 25 False
# 222 25 False
# 279 25 False
# 145 25 False
# 90 25 False
# 271 25 False
# 44 25 False
# 264 25 False
# 268 25 False
# 256 25 False
# 15 25 False
# 207 25 False
# 14 25 False
# 193 25 False
# 78 25 False
# 185 25 False
# 159 25 False
# 24 25 False
# 277 25 False
# 343 25 False
# 354 25 False
# 406 25 False
# 417 25 False
# 424 25 False
# 450 25 False
# 452 25 False
# 453 25 False
# 458 25 False
# 503 25 False
# 504 25 False
# 518 25 False
# 525 25 False
# 520 25 False
# 517 25 False
# 533 25 False
# 537 25 False
# 560 25 False
# 577 25 False
# 555 25 False
# 588 25 False
# 614 25 False
# 625 25 False
# 632 25 False
# 636 25 False
# 672 25 False
# 692 25 False
# 703 25 False
# 765 25 False
# 790 25 False
# 823 25 False
# 835 25 False
# 843 25 False
# 848 25 False
# 852 25 False
# 896 25 False
# 897 25 False
# 899 25 False
# 933 25 False
# 936 25 False
# 194 94 False
# 38 94 False
# 301 94 False
# 276 94 False
# 87 94 False
# 222 94 False
# 94 94 False
# 56 94 False
# 307 94 False
# 73 94 False
# 221 94 False
# 245 94 False
# 373 94 False
# 393 94 False
# 407 94 False
# 450 94 False
# 453 94 False
# 495 94 False
# 504 94 False
# 542 94 False
# 545 94 False
# 621 94 False
# 682 94 False
# 690 94 False
# 705 94 False
# 751 94 False
# 774 94 False
# 778 94 False
# 846 94 False
# 881 94 False
# 886 94 False
# 115 8 False
# 194 8 False
# 58 8 False
# 82 8 False
# 85 8 False
# 18 8 False
# 207 8 False
# 148 8 False
# 158 8 False
# 332 8 False
# 334 8 False
# 342 8 False
# 363 8 False
# 379 8 False
# 392 8 False
# 391 8 False
# 398 8 False
# 407 8 False
# 411 8 False
# 435 8 False
# 452 8 False
# 459 8 False
# 468 8 False
# 465 8 False
# 474 8 False
# 543 8 False
# 601 8 False
# 606 8 False
# 608 8 False
# 620 8 False
# 622 8 False
# 654 8 False
# 658 8 False
# 660 8 False
# 684 8 False
# 758 8 False
# 774 8 False
# 805 8 False
# 838 8 False
# 847 8 False
# 854 8 False
# 875 8 False
# 878 8 False
# 883 8 False
# 889 8 False
# 896 8 False
# 196 70 False
# 6 70 False
# 210 70 False
# 303 70 False
# 119 70 False
# 201 70 False
# 293 70 False
# 271 70 False
# 58 70 False
# 84 70 False
# 213 70 False
# 207 70 False
# 16 70 False
# 270 70 False
# 109 70 False
# 280 70 False
# 13 78 False
# 399 78 False
# 472 78 False
# 620 78 False
# 796 78 False
# 95 73 False
# 7 73 False
# 87 73 False
# 60 73 False
# 82 73 False
# 1 73 False
# 125 73 False
# 23 73 False
# 399 73 False
# 405 73 False
# 435 73 False
# 454 73 False
# 453 73 False
# 474 73 False
# 559 73 False
# 618 73 False
# 650 73 False
# 682 73 False
# 715 73 False
# 846 73 False
# 897 73 False
# 933 73 False
# 94 34 False
# 201 57 False
# 11 57 False
# 90 57 False
# 1 57 False
# 297 57 False
# 455 57 False
# 457 57 False
# 458 57 False
# 639 57 False
# 664 57 False
# 878 57 False
# 291 41 False
# 130 41 False
# 472 41 False
# 642 41 False
# 303 63 False
# 94 63 False
# 5 63 False
# 83 63 False
# 65 63 False
# 399 63 False
# 504 63 False
# 506 63 False
# 536 63 False
# 621 63 False
# 684 63 False
# 747 63 False
# 756 63 False
# 303 43 False
# 95 43 False
# 290 43 False
# 92 43 False
# 1 43 False
# 378 43 False
# 416 43 False
# 436 43 False
# 487 43 False
# 551 43 False
# 922 43 False
# 276 5 False
# 72 5 False
# 293 5 False
# 28 5 False
# 207 5 False
# 218 5 False
# 280 5 False
# 118 5 False
# 311 5 False
# 368 5 False
# 393 5 False
# 399 5 False
# 425 5 False
# 435 5 False
# 437 5 False
# 447 5 False
# 546 5 False
# 562 5 False
# 633 5 False
# 709 5 False
# 814 5 False
# 886 5 False
# 907 5 False
# 276 46 False
# 1 46 False
# 315 46 False
# 387 46 False
# 405 46 False
# 655 46 False
# 321 30 False
# 339 30 False
# 381 30 False
# 500 30 False
# 537 30 False
# 295 84 False
# 85 27 False
# 268 27 False
# 1 27 False
# 221 27 False
# 387 27 False
# 405 27 False
# 416 27 False
# 466 27 False
# 671 27 False
# 851 27 False
# 896 27 False
# 63 10 False
# 181 10 False
# 201 10 False
# 292 10 False
# 90 10 False
# 158 10 False
# 239 10 False
# 343 10 False
# 406 10 False
# 435 10 False
# 430 10 False
# 662 10 False
# 711 10 False
# 765 10 False
# 788 10 False
# 790 10 False
# 804 10 False
# 861 10 False
# 870 10 False
# 886 10 False
# 906 10 False
# 339 74 False
# 617 74 False
# 843 74 False
# 254 35 False
# 83 35 False
# 405 35 False
# 450 35 False
# 620 35 False
# 181 6 False
# 79 6 False
# 655 6 False
# 87 39 False
# 94 39 False
# 259 39 False
# 49 39 False
# 218 39 False
# 197 39 False
# 374 39 False
# 425 39 False
# 435 39 False
# 497 39 False
# 548 39 False
# 648 39 False
# 738 39 False
# 880 39 False
# 90 18 False
# 201 37 False
# 385 37 False
# 293 36 False
# 256 36 False
# 1 36 False
# 314 36 False
# 393 36 False
# 504 75 False
# 682 75 False

# %% [markdown]
# <div class  = "alert alert-success">**EXERCISE 3**<p>
# Modify the similarity function with the following:
# $$new\_sim(a,b) = sim(a,b) * \frac{min(50,|P_{ab}|)}{50} $$
# where $|P_{ab}|$ is the number of common items with user $a$ and user $b$
# </div>

# %% [markdown]
# <div class  = "alert alert-success">**EXERCISE 4**<p>
# Is there a set of users where the systems work better than with othes users?
# Does it depend on the number of rating per user?
# </div>
